# %%
# Import pandas and numpy
import pandas as pd
import numpy as np

# Assuming pf_returns, pf_AUM, and months are available in workspace

# Calculate total rate of return from portfolio AUM
total_return = (pf_AUM[-1] - pf_AUM[0]) / pf_AUM[0]
print(total_return)
