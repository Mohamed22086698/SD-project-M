# %%
# Import pandas, numpy, and matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming factor_data is available in workspace

# Calculate the pairwise correlation
factor_data.corr()
