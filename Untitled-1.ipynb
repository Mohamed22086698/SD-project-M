# %%
# Import pandas and numpy
import pandas as pd
import numpy as np

# Assuming data, returns, and weights are available in workspace

# Create portfolio returns column
returns['Portfolio'] = returns.dot(weights)
