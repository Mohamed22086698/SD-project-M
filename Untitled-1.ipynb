# %%
# Import pandas and numpy
import pandas as pd
import numpy as np

# Assuming portfolio_data is available in workspace

# Calculate return of the portfolio
total_return_pf = (portfolio_data['pf_weights'] * portfolio_data['mean_returns']).sum()
print(total_return_pf)
