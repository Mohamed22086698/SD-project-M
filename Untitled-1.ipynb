# %%
# Import pandas
import pandas as pd

# Assuming returns_sp500 is available in workspace

# Set the index to datetime
returns_sp500.index = pd.to_datetime(returns_sp500.index)

# Ensure the returns are a series
returns = returns_sp500['sp500']

# Check the type
print(type(returns))
